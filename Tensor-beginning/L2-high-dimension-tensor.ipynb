# %%
import torch
x= torch.arange(18).view(3,2,3)
# return 3 block, each block contain two rows and three columns

# %% [markdown]
# supporse this is a building with three floors,
#
#
# 0    [ 0,  1,  2],
#      [ 3,  4,  5]
#
# 1    [ 6,  7,  8],
#      [ 9, 10, 11]
#
# 2        [12, 13, 14],
#          [15, 16, 17]
#
# Within each floor, suppose it is a room, with rows and columns.
#
# if we want to access number 17, it is on third floor, second row and third column. Since our index begin with 0,

# %%
x [2, 1, 2]
# Out:
# tensor(17)

# %%
#how about aceess number of 10?
x [1,1,1]
# Out:
# tensor(10)

# %%
#what about slice elements? if we want to slice the whole second floor
x [1, 0:2, 0:3]
# Out:
# tensor([[ 6,  7,  8],
#         [ 9, 10, 11]])

# %%
# since we select all the rows and columns, we can omit is using :
x [1, :, :]
# Out:
# tensor([[ 6,  7,  8],
#         [ 9, 10, 11]])

# %%
# only slice [6,7,8]

x [1, 0:1, 0:3]
# Out:
# tensor([[6, 7, 8]])

# %% [markdown]
# **matrix multiplication A*B**
#
# must ensure the column of matrix A equals to rows of matrix B

# %%
mat_a = torch.tensor ([0,3,5,5,5,2]).view(2,3)
mat_a
# Out:
# tensor([[0, 3, 5],
#         [5, 5, 2]])

# %%
mat_b = torch.tensor([3,4,3,-2,4,-2]).view(3,2)
mat_b
# Out:
# tensor([[ 3,  4],
#         [ 3, -2],
#         [ 4, -2]])

# %%
mat_a @ mat_b
# Out:
# tensor([[ 29, -16],
#         [ 38,   6]])
